# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1 = pd.read_csv("data/file1.csv")
file2 = pd.read_csv("data/file2.csv")
file3 = pd.read_csv("data/file3.csv")

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %% [markdown]
# ***<br>Standardizing header names<br>***

# %%
def rename_columns(file1):
    file1.rename(columns={'Customer':'id','ST':'state',
                          'GENDER':'gender',"Education":"education", 
                          "Customer Lifetime Value":"customer_lifetime_value","Income": "income",
                          "Monthly Premium Auto":"monthly_premium","Number of Open Complaints":"open_complaints","Policy Type":"policy_type","Vehicle Class":"vehicle_class","Total Claim Amount":"total_claim_amount"}, inplace=True )
    return file1

# %%
file1=rename_columns(file1)

# %%
file1.head()
# Out:
#         id       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium open_complaints     policy_type  vehicle_class  \
# 0      0.0           1000.0          1/0/00   Personal Auto  Four-Door Car
# 1      0.0             94.0          1/0/00   Personal Auto  Four-Door Car
# 2  48767.0            108.0          1/0/00   Personal Auto   Two-Door Car
# 3      0.0            106.0          1/0/00  Corporate Auto            SUV
# 4  36357.0             68.0          1/0/00   Personal Auto  Four-Door Car
#
#    total_claim_amount
# 0            2.704934
# ...

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
def rename_columns(file2):
    file2.rename(columns={'Customer':'id','ST':'state',
                          'GENDER':'gender',"Education":"education", 
                          "Customer Lifetime Value":"customer_lifetime_value","Income": "income",
                          "Monthly Premium Auto":"monthly_premium","Number of Open Complaints":"open_complaints","Policy Type":"policy_type","Vehicle Class":"vehicle_class","Total Claim Amount":"total_claim_amount"}, inplace=True )
    return file2

# %%
file2=rename_columns(file2)

# %%
file2.head()
# Out:
#         id       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium open_complaints  total_claim_amount     policy_type  \
# 0               88          1/0/00               633.6   Personal Auto
# 1              114          1/0/00               547.2    Special Auto
# 2              112          1/0/00               537.6   Personal Auto
# 3              214          1/1/00              1027.2   Personal Auto
# 4               94          1/0/00               451.2  Corporate Auto
#
#    vehicle_class
# 0  Four-Door Car
# 1            SUV
# 2   Two-Door Car
# 3     Luxury Car
# ...

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
def rename_columns(file3):
    file3.rename(columns={'Customer':'id','State':'state',
                          'Gender':'gender',"Education":"education", 
                          "Customer Lifetime Value":"customer_lifetime_value","Income":"income",
                          "Monthly Premium Auto":"monthly_premium","Number of Open Complaints":"open_complaints","Policy Type":"policy_type","Vehicle Class":"vehicle_class","Total Claim Amount":"total_claim_amount"}, inplace=True )
    return file3

# %%
file3=rename_columns(file3)

# %%
file3.head()
# Out:
#         id       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium  open_complaints    policy_type  \
# 0       0              104                0  Personal Auto
# 1       0               66                0  Personal Auto
# 2   25820               82                0  Personal Auto
# 3       0              121                0  Personal Auto
# 4   30366              101                2  Personal Auto
#
#    total_claim_amount  vehicle_class
# 0          499.200000   Two-Door Car
# 1            3.468912   Two-Door Car
# ...

# %% [markdown]
# ***<br>Rearranging columns<br>***

# %%
file1 = file1[[
'id','gender','state','education','income','vehicle_class','policy_type','monthly_premium','customer_lifetime_value','total_claim_amount','open_complaints']]

# %%
file1.head()
# Out:
#         id gender       state             education   income  vehicle_class  \
# 0  RB50392    NaN  Washington                Master      0.0  Four-Door Car
# 1  QZ44356      F     Arizona              Bachelor      0.0  Four-Door Car
# 2  AI49188      F      Nevada              Bachelor  48767.0   Two-Door Car
# 3  WW63253      M  California              Bachelor      0.0            SUV
# 4  GA49547      M  Washington  High School or Below  36357.0  Four-Door Car
#
#       policy_type  monthly_premium customer_lifetime_value  \
# 0   Personal Auto           1000.0                     NaN
# 1   Personal Auto             94.0              697953.59%
# 2   Personal Auto            108.0             1288743.17%
# 3  Corporate Auto            106.0              764586.18%
# 4   Personal Auto             68.0              536307.65%
#
#    total_claim_amount open_complaints
# 0            2.704934          1/0/00
# 1         1131.464935          1/0/00
# ...

# %%
file2 = file2[[
'id','gender','state','education','income','vehicle_class','policy_type','monthly_premium','customer_lifetime_value','total_claim_amount','open_complaints']]

# %%
file3 = file3[[
'id','gender','state','education','income','vehicle_class','policy_type','monthly_premium','customer_lifetime_value','total_claim_amount','open_complaints']]

# %% [markdown]
# ***<br>Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints )<br>***

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1071 non-null   object
#  1   gender                   954 non-null    object
#  2   state                    1071 non-null   object
#  3   education                1071 non-null   object
#  4   income                   1071 non-null   float64
#  5   vehicle_class            1071 non-null   object
#  6   policy_type              1071 non-null   object
#  7   monthly_premium          1071 non-null   float64
#  8   customer_lifetime_value  1068 non-null   object
#  9   total_claim_amount       1071 non-null   float64
#  10  open_complaints          1071 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       996 non-null    object
#  1   gender                   991 non-null    object
#  2   state                    996 non-null    object
#  3   education                996 non-null    object
#  4   income                   996 non-null    int64
#  5   vehicle_class            996 non-null    object
#  6   policy_type              996 non-null    object
#  7   monthly_premium          996 non-null    int64
#  8   customer_lifetime_value  992 non-null    object
#  9   total_claim_amount       996 non-null    float64
#  10  open_complaints          996 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       7070 non-null   object
#  1   gender                   7070 non-null   object
#  2   state                    7070 non-null   object
#  3   education                7070 non-null   object
#  4   income                   7070 non-null   int64
#  5   vehicle_class            7070 non-null   object
#  6   policy_type              7070 non-null   object
#  7   monthly_premium          7070 non-null   int64
#  8   customer_lifetime_value  7070 non-null   float64
#  9   total_claim_amount       7070 non-null   float64
#  10  open_complaints          7070 non-null   int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
file2['income'] = file2['income'].astype('float')

# %%
file3['income'] = file3['income'].astype('float')

# %%
file2['monthly_premium'] = file2['monthly_premium'].astype('float')

# %%
file1
# Out:
#            id gender       state             education   income  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 4003      NaN    NaN         NaN                   NaN      NaN
# 4004      NaN    NaN         NaN                   NaN      NaN
# 4005      NaN    NaN         NaN                   NaN      NaN
# 4006      NaN    NaN         NaN                   NaN      NaN
# 4007      NaN    NaN         NaN                   NaN      NaN
#
#       vehicle_class     policy_type  monthly_premium customer_lifetime_value  \
# 0     Four-Door Car   Personal Auto           1000.0                     NaN
# ...

# %%
file2
# Out:
#           id gender       state education   income  vehicle_class  \
# 0    GS98873      F     Arizona  Bachelor  16061.0  Four-Door Car
# 1    CW49887      F  California    Master  79487.0            SUV
# 2    MY31220      F  California   College  54230.0   Two-Door Car
# 3    UH35128      F      Oregon   College  71210.0     Luxury Car
# 4    WH52799      F     Arizona   College  94903.0   Two-Door Car
# ..       ...    ...         ...       ...      ...            ...
# 991  HV85198      M     Arizona    Master  63513.0  Four-Door Car
# 992  BS91566      F     Arizona   College  58161.0  Four-Door Car
# 993  IL40123      F      Nevada   College  83640.0   Two-Door Car
# 994  MY32149      F  California    Master      0.0   Two-Door Car
# 995  SA91515      M  California  Bachelor      0.0            SUV
#
#         policy_type  monthly_premium customer_lifetime_value  \
# 0     Personal Auto             88.0              323912.47%
# ...

# %%
file3
# Out:
#            id gender       state             education   income  \
# 0     SA25987      M  Washington  High School or Below      0.0
# 1     TB86706      M     Arizona                Master      0.0
# 2     ZL73902      F      Nevada              Bachelor  25820.0
# 3     KX23516      F  California  High School or Below      0.0
# 4     FN77294      M  California  High School or Below  30366.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       vehicle_class     policy_type  monthly_premium  customer_lifetime_value  \
# 0      Two-Door Car   Personal Auto              104              3479.137523
# ...

# %%
file1['customer_lifetime_value']=file1['customer_lifetime_value'].str.rstrip("%").astype(float)/100

# %%
file2['customer_lifetime_value']=file2['customer_lifetime_value'].str.rstrip("%").astype(float)/100

# %% [markdown]
# ***<br>Clean the number of open complaints and extract the middle number which is changing between records<br>***

# %%
file2['open_complaints'] = file2['open_complaints'].str[2:3]

# %%
file2
# Out:
#           id gender       state education   income  vehicle_class  \
# 0    GS98873      F     Arizona  Bachelor  16061.0  Four-Door Car
# 1    CW49887      F  California    Master  79487.0            SUV
# 2    MY31220      F  California   College  54230.0   Two-Door Car
# 3    UH35128      F      Oregon   College  71210.0     Luxury Car
# 4    WH52799      F     Arizona   College  94903.0   Two-Door Car
# ..       ...    ...         ...       ...      ...            ...
# 991  HV85198      M     Arizona    Master  63513.0  Four-Door Car
# 992  BS91566      F     Arizona   College  58161.0  Four-Door Car
# 993  IL40123      F      Nevada   College  83640.0   Two-Door Car
# 994  MY32149      F  California    Master      0.0   Two-Door Car
# 995  SA91515      M  California  Bachelor      0.0            SUV
#
#         policy_type  monthly_premium  customer_lifetime_value  \
# 0     Personal Auto             88.0                3239.1247
# ...

# %%
file1['open_complaints'] = file1['open_complaints'].str[2:3]

# %%
print(file3['open_complaints'].unique())
# Out:
# [0 2 3 1 5 4]

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       1071 non-null   object
#  1   gender                   954 non-null    object
#  2   state                    1071 non-null   object
#  3   education                1071 non-null   object
#  4   income                   1071 non-null   float64
#  5   vehicle_class            1071 non-null   object
#  6   policy_type              1071 non-null   object
#  7   monthly_premium          1071 non-null   float64
#  8   customer_lifetime_value  1068 non-null   float64
#  9   total_claim_amount       1071 non-null   float64
#  10  open_complaints          1071 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 344.6+ KB

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       996 non-null    object
#  1   gender                   991 non-null    object
#  2   state                    996 non-null    object
#  3   education                996 non-null    object
#  4   income                   996 non-null    float64
#  5   vehicle_class            996 non-null    object
#  6   policy_type              996 non-null    object
#  7   monthly_premium          996 non-null    float64
#  8   customer_lifetime_value  992 non-null    float64
#  9   total_claim_amount       996 non-null    float64
#  10  open_complaints          996 non-null    object
# dtypes: float64(4), object(7)
# memory usage: 85.7+ KB

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       7070 non-null   object
#  1   gender                   7070 non-null   object
#  2   state                    7070 non-null   object
#  3   education                7070 non-null   object
#  4   income                   7070 non-null   float64
#  5   vehicle_class            7070 non-null   object
#  6   policy_type              7070 non-null   object
#  7   monthly_premium          7070 non-null   int64
#  8   customer_lifetime_value  7070 non-null   float64
#  9   total_claim_amount       7070 non-null   float64
#  10  open_complaints          7070 non-null   int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 607.7+ KB

# %% [markdown]
# ***<br>Aggregate the data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.<br>***

# %%
cd_df=pd.concat([file1, file2, file3])

# %%
cd_df
# Out:
#            id gender       state             education   income  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       vehicle_class     policy_type  monthly_premium  customer_lifetime_value  \
# 0     Four-Door Car   Personal Auto           1000.0                      NaN
# ...

# %% [markdown]
# ***<br>Removing duplicates<br>***

# %%
cd_df.drop_duplicates()
# Out:
#            id gender       state             education   income  \
# 0     RB50392    NaN  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       vehicle_class     policy_type  monthly_premium  customer_lifetime_value  \
# 0     Four-Door Car   Personal Auto           1000.0                      NaN
# ...

# %% [markdown]
# ***<br>Filtering data and Correcting typos<br>***

# %%
print(cd_df['gender'].unique())
# Out:
# [nan 'F' 'M' 'Femal' 'Male' 'female']

# %%
def clean_gender(x):
    if x in ['M','Male']:
        return 'M'
    elif x in ['F','Femal', 'female']:
        return 'F'
    elif np.nan:  pass
    else:
        return 'U'

# %%
cd_df['gender'] = list(map(clean_gender, cd_df['gender']))

# %%
print(cd_df['gender'].unique())
# Out:
# [None 'F' 'M']

# %%
cd_df
# Out:
#            id gender       state             education   income  \
# 0     RB50392   None  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       vehicle_class     policy_type  monthly_premium  customer_lifetime_value  \
# 0     Four-Door Car   Personal Auto           1000.0                      NaN
# ...

# %%
print(cd_df['state'].unique())
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA'
#  nan]

# %%
def clean_state(x):
    if x in ['Arizona','AZ']:
        return 'Arizona'
    elif x in ['Washington','WA']:
        return 'Washington'
    elif x in ['California','Cali']:
        return 'California'
    elif x in ['Nevada']:
        return 'Nevada'
    elif x in ['Oregon']:
        return 'Oregon'    
    elif np.nan:  pass
    else: pass

# %%
cd_df['state'] = list(map(clean_state, cd_df['state']))

# %%
print(cd_df['state'].unique())
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' None]

# %%
cd_df
# Out:
#            id gender       state             education   income  \
# 0     RB50392   None  Washington                Master      0.0
# 1     QZ44356      F     Arizona              Bachelor      0.0
# 2     AI49188      F      Nevada              Bachelor  48767.0
# 3     WW63253      M  California              Bachelor      0.0
# 4     GA49547      M  Washington  High School or Below  36357.0
# ...       ...    ...         ...                   ...      ...
# 7065  LA72316      M  California              Bachelor  71941.0
# 7066  PK87824      F  California               College  21604.0
# 7067  TD14365      M  California              Bachelor      0.0
# 7068  UP19263      M  California               College  21941.0
# 7069  Y167826      M  California               College      0.0
#
#       vehicle_class     policy_type  monthly_premium  customer_lifetime_value  \
# 0     Four-Door Car   Personal Auto           1000.0                      NaN
# ...

# %%
cd_df.drop(columns=['id']) # I REALLY hate to drop an id column so no cd_df=... here ;)!
# Out:
#      gender       state             education   income  vehicle_class  \
# 0      None  Washington                Master      0.0  Four-Door Car
# 1         F     Arizona              Bachelor      0.0  Four-Door Car
# 2         F      Nevada              Bachelor  48767.0   Two-Door Car
# 3         M  California              Bachelor      0.0            SUV
# 4         M  Washington  High School or Below  36357.0  Four-Door Car
# ...     ...         ...                   ...      ...            ...
# 7065      M  California              Bachelor  71941.0  Four-Door Car
# 7066      F  California               College  21604.0  Four-Door Car
# 7067      M  California              Bachelor      0.0  Four-Door Car
# 7068      M  California               College  21941.0  Four-Door Car
# 7069      M  California               College      0.0   Two-Door Car
#
#          policy_type  monthly_premium  customer_lifetime_value  \
# ...

# %% [markdown]
# ***<br>Removing duplicates<br>***

# %%
cd_df=cd_df.drop_duplicates()
cd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9135 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       9134 non-null   object
#  1   gender                   9012 non-null   object
#  2   state                    9134 non-null   object
#  3   education                9134 non-null   object
#  4   income                   9134 non-null   float64
#  5   vehicle_class            9134 non-null   object
#  6   policy_type              9134 non-null   object
#  7   monthly_premium          9134 non-null   float64
#  8   customer_lifetime_value  9127 non-null   float64
#  9   total_claim_amount       9134 non-null   float64
#  10  open_complaints          9134 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 856.4+ KB

# %%
xpoints = np.array(cd_df['customer_lifetime_value'])
ypoints = np.array(cd_df['total_claim_amount'])

plt.plot(xpoints, ypoints, '.')
plt.show()

# %%
sns.jointplot(data=cd_df, x='customer_lifetime_value', y='total_claim_amount', kind="reg")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2636\50482948.py in <module>
# ----> 1 sns.jointplot(data=cd_df, x='customer_lifetime_value', y='total_claim_amount', kind="reg")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
cd_df.reset_index()

# %%
cd_df[cd_df['state'].isna()==True]

# %%
cd_df=cd_df.drop([1071])

# %%
cd_df[cd_df['state'].isna()==True]

# %%
cd_df.head()

# %%
cd_df['customer_lifetime_value'] = cd_df['customer_lifetime_value'].round()

# %%
cd_df.head()

# %% [markdown]
# ***<br>Replace missing values with means of the column<br>***

# %%
inc_df = len(cd_df[cd_df["income"]==0])

# %%
print(inc_df)

# %%
cd_df['income'] = cd_df['income'].replace(0, np.nan)

# %%
cd_df.head()

# %%
mean_income = np.mean(cd_df['income'])

# %%
cd_df['income'] = cd_df['income'].fillna(mean_income)
cd_df['income'] = cd_df['income'].round(2)

# %%
cd_df.head()

# %%
cd_df[cd_df['customer_lifetime_value'].isna()==True]

# %%
mean_clv = np.mean(cd_df['customer_lifetime_value'])
cd_df['customer_lifetime_value'] = cd_df['customer_lifetime_value'].fillna(mean_clv)
cd_df['customer_lifetime_value'] = cd_df['customer_lifetime_value'].round()

# %%
print(mean_clv)
print(mean_income)

# %%
cd_df.head()

# %% [markdown]
# ***<br>Bucketing the data<br>***

# %%
def region(state):
    if state in ['California']:
        return 'West'
    elif state in ['Oregon']:
        return 'North West'
    elif state in ['Washington']:
        return 'East'
    elif state in ['Arizona', 'Nevada']:
        return 'Central'
    elif np.nan:  pass
    else: pass

# %%
cd_df.insert(3, 'region', cd_df['state'].map(region))

# %%
cd_df.head()

# %% [markdown]
# ***<br>In the column Vehicle Class, merge the two categories Luxury SUV and Luxury Car<br>***

# %%
cd_df['vehicle_class'] = cd_df['vehicle_class'].replace(['Luxury SUV', 'Luxury Car'], 'Luxury Vehicle')

# %%
print(cd_df['vehicle_class'].unique())

# %%
cd_df['customer_lifetime_value'] = cd_df['customer_lifetime_value'].astype('int')

# %% [markdown]
# ***<br>Removing outliers using 1.5 x IQR technique for all numerical columns<br>***

# %%
cd_df.info()

# %%
num_cols = cd_df.select_dtypes(include=['int', 'float']).columns.tolist()

# %%
print(num_cols)

# %%
Q_25 = cd_df[num_cols].quantile(0.25)
Q_75 = cd_df[num_cols].quantile(0.75)
IQR = Q_75 - Q_25

# %%
Q_25

# %%
Q_75

# %%
IQR

# %%
cd_df.head()

# %%
Q_25['income']

# %%
def remove_lower_outlier(dataFrame, col_name):
    threshold = Q_25[col_name]-(IQR[col_name]*1.5)
    return dataFrame[dataFrame[col_name] > threshold]

# %%
def remove_higher_outlier(dataFrame, col_name):
    threshold = Q_75[col_name]+(IQR[col_name]*1.5)
    return dataFrame[dataFrame[col_name] < threshold]

# %%
cd_df[cd_df.monthly_premium > (Q_75['monthly_premium']+(IQR['monthly_premium']*1.5))]

# %%
cd_df = remove_higher_outlier(cd_df,'monthly_premium')

# %%
cd_df = remove_lower_outlier(cd_df,'monthly_premium')

# %%
cd_df = remove_higher_outlier(cd_df,'income')
cd_df = remove_higher_outlier(cd_df,'customer_lifetime_value')
cd_df = remove_higher_outlier(cd_df,'total_claim_amount')
cd_df = remove_lower_outlier(cd_df,'income')
cd_df = remove_lower_outlier(cd_df,'customer_lifetime_value')
cd_df = remove_lower_outlier(cd_df,'total_claim_amount')

# %%
cd_df.info()

# %% [markdown]
# ***Standardizing the data***

# %%
str_cols = cd_df.select_dtypes(include=[object]).columns.tolist()

# %%
print(str_cols)

# %%
cd_df = cd_df.apply(lambda x: x.astype(str).str.lower())

# %%
cd_df['total_claim_amount'] = cd_df['total_claim_amount'].astype('float')
cd_df['total_claim_amount'] = cd_df['total_claim_amount'].round(2)

# %%
cd_df.reset_index()

# %%
cd_df.to_csv('customer_data.csv')

# %%
xpoints = np.array(cd_df['customer_lifetime_value'])
ypoints = np.array(cd_df['total_claim_amount'])

plt.plot(xpoints, ypoints, '.')
plt.show()
