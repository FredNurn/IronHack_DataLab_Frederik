# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
basic_file= pd.read_csv("data/Data_Marketing_Customer_Analysis_Round3.csv")

# %%
basic_file.head()
# Out:
#         region  customer_lifetime_value response  coverage education  \
# 0      central                     4809       no     basic   college
# 1  west region                     2228       no     basic   college
# 2         east                    14947       no     basic  bachelor
# 3   north west                    22332      yes  extended   college
# 4   north west                     9025       no   premium  bachelor
#
#   effective_to_date month employment_status gender  income  ...  \
# 0           2/18/11   feb          employed      m   48029  ...
# 1           1/18/11   jan        unemployed      f   92260  ...
# 2           2/10/11   feb          employed      m   22139  ...
# 3           1/11/11   jan          employed      m   49078  ...
# 4           1/17/11   jan     medical leave      f   23675  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                            52                         0                   9
# ...

# %%
basic_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %% [markdown]
# **<br>Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals<br>**

# %%
numerical_df = basic_file.select_dtypes(include='int64')
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_lifetime_value        10689 non-null  int64
#  1   income                         10689 non-null  int64
#  2   monthly_premium_auto           10689 non-null  int64
#  3   months_since_last_claim        10689 non-null  int64
#  4   months_since_policy_inception  10689 non-null  int64
#  5   number_of_open_complaints      10689 non-null  int64
#  6   number_of_policies             10689 non-null  int64
#  7   total_claim_amount             10689 non-null  int64
# dtypes: int64(8)
# memory usage: 668.2 KB

# %%
numerical_df.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             10689.000000  10689.000000          10689.000000
# mean               8011.906727  51750.243989             93.190196
# std                6877.557889  24778.053035             34.413111
# min                1898.000000  10037.000000             61.000000
# 25%                4014.000000  29335.000000             68.000000
# 50%                5776.000000  50398.000000             83.000000
# 75%                8991.000000  72131.000000            109.000000
# max               83325.000000  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count             10689.000000                   10689.000000
# mean                 15.144073                      48.100571
# std                  10.086110                      27.934300
# min                   0.000000                       0.000000
# ...

# %%
categoricals_df = basic_file.select_dtypes(include='object')
categoricals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   effective_to_date  10689 non-null  object
#  5   month              10689 non-null  object
#  6   employment_status  10689 non-null  object
#  7   gender             10689 non-null  object
#  8   location_code      10689 non-null  object
#  9   marital_status     10689 non-null  object
#  10  policy_type        10689 non-null  object
#  11  policy             10689 non-null  object
#  12  renew_offer_type   10689 non-null  object
#  13  sales_channel      10689 non-null  object
#  14  vehicle_class      10689 non-null  object
#  15  vehicle_size       10689 non-null  object
# ...

# %%
categoricals_df.describe()
# Out:
#              region response coverage education effective_to_date  month  \
# count         10689    10689    10689     10689             10689  10689
# unique            4        2        3         5                59      2
# top     west region       no    basic  bachelor           1/27/11    jan
# freq           3678     9316     6523      3210               236   5684
#
#        employment_status gender location_code marital_status    policy_type  \
# count              10689  10689         10689          10689          10689
# unique                 5      2             3              3              3
# top             employed      f      suburban        married  personal auto
# freq                6658   5469          6742           6199           7937
#
#              policy renew_offer_type sales_channel  vehicle_class vehicle_size
# count         10689            10689         10689          10689        10689
# ...

# %% [markdown]
# **<br>Try to check the normality of the numerical variables visually<br>**

# %% [markdown]
# **<br>Use seaborn library to construct distribution plots for the numerical variables<br>**

# %%
fig, ax = plt.subplots(3, 3, figsize=(20,20))

sns.histplot(numerical_df['customer_lifetime_value'], kde=False, label='All values', 
             ax=ax[0, 0])
sns.histplot(numerical_df['income'], kde=False, label='All values', 
             ax=ax[0, 1])
sns.histplot(numerical_df['monthly_premium_auto'], kde=False, label='All values', 
             ax=ax[0, 2])
sns.histplot(numerical_df['months_since_last_claim'], kde=False, label='All values', 
             ax=ax[1, 0])
sns.histplot(numerical_df['months_since_policy_inception'], kde=False, label='All values', 
             ax=ax[1, 1])
sns.histplot(numerical_df['number_of_open_complaints'], kde=False, label='All values', 
             ax=ax[1, 2])
sns.histplot(numerical_df['number_of_policies'], kde=False, label='All values', 
             ax=ax[2, 0])
sns.histplot(numerical_df['total_claim_amount'], kde=False, label='All values', 
             ax=ax[2, 1])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Count'>

# %% [markdown]
# **<br>Use Matplotlib to construct histograms.<br>**

# %%
## first axis
fig2=plt.figure(figsize=(20,20))

plt.subplot(3,3,1)
plt.hist(numerical_df.customer_lifetime_value)
plt.xlabel("Customer Lifetime Value")
plt.ylabel("Count")

#second axis
plt.subplot(3,3,2)
plt.hist(numerical_df.income)
plt.xlabel("Income")
plt.ylabel("Count")

##. third subplot
plt.subplot(3,3,3)
plt.hist(numerical_df.monthly_premium_auto)
plt.xlabel("Monthly Premium Auto")
plt.ylabel("Count")

## fourth subplot
plt.subplot(3,3,4)
plt.hist(numerical_df.months_since_last_claim)
plt.xlabel("Months since last Claim")
plt.ylabel("Count")

## fourth subplot
plt.subplot(3,3,5)
plt.hist(numerical_df.months_since_policy_inception)
plt.xlabel("Months since Policy Inception")
plt.ylabel("Count")

## fourth subplot
plt.subplot(3,3,6)
plt.hist(numerical_df.number_of_open_complaints)
plt.xlabel("Number of open Complaints")
plt.ylabel("Count")

## fourth subplot
plt.subplot(3,3,7)
plt.hist(numerical_df.number_of_policies)
plt.xlabel("Number of Policies")
plt.ylabel("Count")

## fourth subplot
plt.subplot(3,3,8)
plt.hist(numerical_df.total_claim_amount)
plt.xlabel("Total Claim Amount")
plt.ylabel("Count")

plt.suptitle("Use Matplotlib to construct histograms:")
# Out:
# Text(0.5, 0.98, 'Use Matplotlib to construct histograms:')

# %% [markdown]
# **<br>Do the distributions for different numerical variables look like a normal distribution?<br>**

# %% [markdown]
# No.

# %% [markdown]
# **<br>For the numerical variables, check for correlation between the input features.<br>**

# %%
numerical_df2 = numerical_df.drop(columns=['total_claim_amount'])
df3 = numerical_df2.corr()
df3.to_excel(r'data/Customer_Analysis_corrheatmap.xlsx', index=False)

# %% [markdown]
# **<br>Plot the Correlation Heatmap.<br>**

# %%
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(numerical_df2.corr(), dtype='bool'))
heatmap = sns.heatmap(numerical_df2.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# **<br>(Optional): Drop one of the two features that show a high correlation between them (greater than 0.9). If there is no pair of features that have a high correlation, then do not drop any features.<br>**

# %% [markdown]
# <br>
# <br>
# *Thursday*
# <br>
# <br>

# %%
categoricals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   effective_to_date  10689 non-null  object
#  5   month              10689 non-null  object
#  6   employment_status  10689 non-null  object
#  7   gender             10689 non-null  object
#  8   location_code      10689 non-null  object
#  9   marital_status     10689 non-null  object
#  10  policy_type        10689 non-null  object
#  11  policy             10689 non-null  object
#  12  renew_offer_type   10689 non-null  object
#  13  sales_channel      10689 non-null  object
#  14  vehicle_class      10689 non-null  object
#  15  vehicle_size       10689 non-null  object
# ...

# %%
categoricals_df.head()
# Out:
#         region response  coverage education effective_to_date month  \
# 0      central       no     basic   college           2/18/11   feb
# 1  west region       no     basic   college           1/18/11   jan
# 2         east       no     basic  bachelor           2/10/11   feb
# 3   north west      yes  extended   college           1/11/11   jan
# 4   north west       no   premium  bachelor           1/17/11   jan
#
#   employment_status gender location_code marital_status     policy_type  \
# 0          employed      m      suburban        married  corporate auto
# 1        unemployed      f      suburban         single   personal auto
# 2          employed      m      suburban         single   personal auto
# 3          employed      m      suburban         single  corporate auto
# 4     medical leave      f      suburban        married   personal auto
#
#          policy renew_offer_type sales_channel  vehicle_class vehicle_size
# ...

# %% [markdown]
# **<br>Show a plot of the total number of responses.<br>**

# %%
basic_file['response'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **<br>Show a plot of the response by the sales channel.<br>**

# %%
index = list(range(0,len(basic_file)))

# %%
basic_file['index']=index

response_channel = basic_file.groupby(['response','sales_channel'])['index'].count().reset_index()
response_channel
# Out:
#   response sales_channel  index
# 0       no         agent   3340
# 1       no        branch   2665
# 2       no   call center   1890
# 3       no           web   1421
# 4      yes         agent    679
# 5      yes        branch    310
# 6      yes   call center    209
# 7      yes           web    175

# %%
plt.figure(figsize=(10,7))
plt.title('Response by Sales Channel', size='25', fontweight='bold')

sns.barplot(x = response_channel['sales_channel'],y = response_channel['index'], hue = response_channel['response'])
# Out:
# <AxesSubplot:title={'center':'Response by Sales Channel'}, xlabel='sales_channel', ylabel='index'>

# %% [markdown]
# **<br>Show a plot of the response by the total claim amount.<br>**

# %%
plt.figure(figsize=(7,7))
plt.title('Response by Average TCA', size='18', fontweight='bold')

sns.barplot(x = basic_file['response'],y = basic_file[('total_claim_amount')])
# Out:
# <AxesSubplot:title={'center':'Response by Average TCA'}, xlabel='response', ylabel='total_claim_amount'>

# %%
mean = numerical_df["total_claim_amount"].mean()
print(mean)
# Out:
# 434.22724296005237

# %%
plt.figure(figsize=(10,10))
plt.title('Response by Sum TCA', size='18', fontweight='bold')

sns.barplot(x = basic_file['response'], y = basic_file[('total_claim_amount')], estimator=sum)
# Out:
# <AxesSubplot:title={'center':'Response by Sum TCA'}, xlabel='response', ylabel='total_claim_amount'>

# %% [markdown]
# **<br>Show a plot of the response by income.<br>**

# %%
basic_file['income_group'] = pd.qcut(basic_file['income'],3, labels=["low", "medium", "high"])

# %%
response_income = basic_file.groupby(['response','income_group'])['index'].count().reset_index()


plt.figure(figsize=(10,7))
plt.title('Response by Income Group', size='25', fontweight='bold')

sns.barplot(x = basic_file['income_group'],y = basic_file['index'], hue = basic_file['response'])
# I know there is a logical error there, but I still have to find it.
# Out:
# <AxesSubplot:title={'center':'Response by Income Group'}, xlabel='income_group', ylabel='index'>

# %% [markdown]
# **<br>(Optional) plot any interesting findings/insights(minimum three) that describe some interesting facts about your data set and its input variables as well as relationships with the target feature.<br>**

# %%
plt.figure(figsize=(7,3))
plt.title('Avg. Income by Car Class ', size='18', fontweight='bold')

sns.barplot(x = basic_file['vehicle_class'],y = basic_file[('income')])
# Out:
# <AxesSubplot:title={'center':'Avg. Income by Car Class '}, xlabel='vehicle_class', ylabel='income'>

# %%
gender_employment = basic_file.groupby(['gender','employment_status'])['index'].count().reset_index()
gender_employment
# Out:
#   gender employment_status  index
# 0      f          disabled    294
# 1      f          employed   3430
# 2      f     medical leave    240
# 3      f           retired    140
# 4      f        unemployed   1365
# 5      m          disabled    195
# 6      m          employed   3228
# 7      m     medical leave    250
# 8      m           retired    161
# 9      m        unemployed   1386

# %%
plt.figure(figsize=(7,3))
plt.title('Employment by Gender', size='25', fontweight='bold')

sns.barplot(x = gender_employment['employment_status'],y = gender_employment['index'], hue = gender_employment['gender'])
# Out:
# <AxesSubplot:title={'center':'Employment by Gender'}, xlabel='employment_status', ylabel='index'>

# %% [markdown]
# **<br>Clean your notebook and make it readable and presentable with a good documentation<br>**
