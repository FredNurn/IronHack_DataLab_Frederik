# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# HO: μ = 120 mm Hg <br>
# H1: μ != 120 mm Hg<br>
# SD = 21.21 mm Hg<br>
#
# The standard deviation of the population is unknown -> we are using Student-t.<br>
# We want to test a nondirectional hypothesis -> two-tailed Test.

# %% [markdown]
# We calculate the critical value:

# %%
print("The critical value is", round(stats.t.ppf(0.95, df=99),4))
# Out:
# The critical value is 1.6604

# %%
t = (130.1-120)/(21.21/math.sqrt(100))
print(round(t,4))
# Out:
# 4.7619

# %% [markdown]
# 4.7619 > 1.6604 -> We can reject H0.

# %% [markdown]
# <br>
# optional
# <br>

# %%
machine_df = pd.read_excel("Machine.xlsx")

# %%
machine_df
# Out:
#    New Machine  Old Machine
# 0         42.1         42.7
# 1         41.0         43.6
# 2         41.3         43.8
# 3         41.8         43.3
# 4         42.4         42.5
# 5         42.8         43.5
# 6         43.2         43.1
# 7         42.3         41.7
# 8         41.8         44.0
# 9         42.7         44.1

# %%
sns.histplot(machine_df['New Machine'],bins=10)
# Out:
# <AxesSubplot:xlabel='New Machine', ylabel='Count'>

# %%
sns.histplot(machine_df['Old Machine'],bins=10)
# Out:
# <AxesSubplot:xlabel='Old Machine', ylabel='Count'>

# %%
mean_old = machine_df["Old Machine"].mean()
mean_old
# Out:
# 43.230000000000004

# %%
mean_new = machine_df["New Machine"].mean()
mean_new
# Out:
# 42.14

# %%
std_old = machine_df['Old Machine'].std()
std_old
# Out:
# 0.7498888806572157

# %%
std_new = machine_df['New Machine'].std()
std_new
# Out:
# 0.6834552736727638

# %%
t= (mean_old-mean_new)/(math.sqrt((std_old**2/10)+(std_new**2/10)))
t
# Out:
# 3.397230706117603

# %%
round(stats.t.ppf(0.975, df=9),4)
# Out:
# 2.2622
