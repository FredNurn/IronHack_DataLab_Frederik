# %%
import spotify_config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
import pandas as pd
import openpyxl

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= spotify_config.client_id, client_secret= spotify_config.client_secret))

# %%
list_of_audio_features=[]

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return results

# %%
#,
#           
#,

# %%
playlists=["37i9dQZF1EQmPV0vrce2QZ","37i9dQZF1DWZBCPUIUs2iR","37i9dQZF1DX47i8ytbYGJE"]

# %%
for playlist in playlists:
    playlist2 = sp.user_playlist_tracks("spotify", playlist)
    tracks = get_playlist_tracks('spotify',playlist)
    for i in range(len(playlist2['items'])):
         list_of_audio_features.append(sp.audio_features(tracks['items'][i]["track"]["id"])[0])

# %%
df=pd.DataFrame(list_of_audio_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
df.drop_duplicates
df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.553   0.723    -5.858       0.0303        0.0248
# 1           0.427   0.278    -8.830       0.0331        0.4700
# 2           0.674   0.537   -10.971       0.0363        0.5660
# 3           0.683   0.796    -4.179       0.0285        0.1110
# 4           0.680   0.870    -4.461       0.0393        0.2660
# ..            ...     ...       ...          ...           ...
# 220         0.475   0.603    -7.989       0.0421        0.4860
# 221         0.733   0.816    -3.395       0.0294        0.7330
# 222         0.914   0.465   -11.406       0.0618        0.6700
# 223         0.639   0.705    -9.878       0.0681        0.5750
# 224         0.514   0.796    -8.226       0.0691        0.5770
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000001     0.252    0.616   88.007  6i33i1yO8ye2tFYkN9C1Dx
# ...

# %%
df.to_excel("audio_features_15.xlsx")
